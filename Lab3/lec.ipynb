# %%
import pandas as pd

# %%
s = pd.Series([5,20,30,35,60])
s
# Out:
# 0     5
# 1    20
# 2    30
# 3    35
# 4    60
# dtype: int64

# %%
s = pd.Series([5,20,30,35,60], index = ['a','b','c','d','e']);
s
# Out:
# a     5
# b    20
# c    30
# d    35
# e    60
# dtype: int64

# %%
s[1]
# Out:
# C:\Users\pawar\AppData\Local\Temp\ipykernel_22276\878419959.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[1]
# 20

# %%
import numpy as np
from numpy import random as rd

# %%
df1 = pd.DataFrame(np.random.randint(10,50,[5,4]))
df1
# Out:
#     0   1   2   3
# 0  40  20  22  20
# 1  42  36  15  36
# 2  40  42  33  16
# 3  49  49  26  46
# 4  24  41  20  12

# %%
df1 = pd.DataFrame(np.random.randint(0,50,[5,4]), 
                   index = ['a','b', 'c' ,'d', 'e'], 
                   columns=list('age tel Y Z'.split()))
df1
# Out:
#    age  tel   Y   Z
# a   40   37  32  42
# b   26   17   0  48
# c   37   18  20  36
# d   37   30  25  47
# e   43   45  46  49

# %%
df1.age
# Out:
# a    40
# b    26
# c    37
# d    37
# e    43
# Name: age, dtype: int32

# %%
df1['tel']
# Out:
# a    37
# b    17
# c    18
# d    30
# e    45
# Name: tel, dtype: int32

# %%
df1['tel']['e']
# Out:
# 45

# %%
df1['Z']['a']
# Out:
# 42

# %%
df1.loc['a']
# Out:
# age    40
# tel    37
# Y      32
# Z      42
# Name: a, dtype: int32

# %%
df1.loc['a']['tel']
# Out:
# 37

# %%
df1.iloc[0][1]
# Out:
# C:\Users\pawar\AppData\Local\Temp\ipykernel_22276\791845183.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df1.iloc[0][1]
# 37

# %%
df1
# Out:
#    age  tel   Y   Z
# a   40   37  32  42
# b   26   17   0  48
# c   37   18  20  36
# d   37   30  25  47
# e   43   45  46  49

# %%
df1[['Y','Z']]
# Out:
#     Y   Z
# a  32  42
# b   0  48
# c  20  36
# d  25  47
# e  46  49

# %%
df1.loc[['b','d']]
# Out:
#    age  tel   Y   Z
# b   26   17   0  48
# d   37   30  25  47

# %%
df1.loc['b':'d',['Y','Z']]
# Out:
#     Y   Z
# b   0  48
# c  20  36
# d  25  47

# %%
df1
# Out:
#    age  tel   Y   Z
# a   40   37  32  42
# b   26   17   0  48
# c   37   18  20  36
# d   37   30  25  47
# e   43   45  46  49

# %%
df1>20
# Out:
#     age    tel      Y     Z
# a  True   True   True  True
# b  True  False  False  True
# c  True  False  False  True
# d  True   True   True  True
# e  True   True   True  True

# %%
df1[df1 > 20]
# Out:
#    age   tel     Y   Z
# a   40  37.0  32.0  42
# b   26   NaN   NaN  48
# c   37   NaN   NaN  36
# d   37  30.0  25.0  47
# e   43  45.0  46.0  49

# %%
df1[df1['age']>20]
# Out:
#    age  tel   Y   Z
# a   40   37  32  42
# b   26   17   0  48
# c   37   18  20  36
# d   37   30  25  47
# e   43   45  46  49

# %%
data = {
  'Company' : ['SCG','SCG','PTT','PTT','KTP','KTB'],
  'Person' : list("ABCDEF"),
  'Sales' : [200,300,450,100,140,350]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Company Person  Sales
# 0     SCG      A    200
# 1     SCG      B    300
# 2     PTT      C    450
# 3     PTT      D    100
# 4     KTP      E    140
# 5     KTB      F    350

# %%
df.groupby('Company')

# %%
df.groupby('Company').sum()
# Out:
#         Person  Sales
# Company
# KTB          F    350
# KTP          E    140
# PTT         CD    550
# SCG         AB    500

# %%
df.groupby('Company').sum()['Sales']
# Out:
# Company
# KTB    350
# KTP    140
# PTT    550
# SCG    500
# Name: Sales, dtype: int64

# %%
df.groupby('Company').sum().loc['PTT']
# Out:
# Person     CD
# Sales     550
# Name: PTT, dtype: object

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min    25%    50%    75%    max
# Company
# KTB       1.0  350.0         NaN  350.0  350.0  350.0  350.0  350.0
# KTP       1.0  140.0         NaN  140.0  140.0  140.0  140.0  140.0
# PTT       2.0  275.0  247.487373  100.0  187.5  275.0  362.5  450.0
# SCG       2.0  250.0   70.710678  200.0  225.0  250.0  275.0  300.0

# %%
df.groupby('Company').describe().transpose()
# Out:
# Company        KTB    KTP         PTT         SCG
# Sales count    1.0    1.0    2.000000    2.000000
#       mean   350.0  140.0  275.000000  250.000000
#       std      NaN    NaN  247.487373   70.710678
#       min    350.0  140.0  100.000000  200.000000
#       25%    350.0  140.0  187.500000  225.000000
#       50%    350.0  140.0  275.000000  250.000000
#       75%    350.0  140.0  362.500000  275.000000
#       max    350.0  140.0  450.000000  300.000000

# %%
df = pd.read_excel('Sample - Superstore.xls')
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Sales'].sort_values()
# Out:
# 4101        0.444
# 9292        0.556
# 8658        0.836
# 4711        0.852
# 2106        0.876
#           ...
# 4190    10499.970
# 2623    11199.968
# 8153    13999.960
# 6826    17499.950
# 2697    22638.480
# Name: Sales, Length: 9994, dtype: float64

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.groupby('Customer Name')['Profit'].sum().max()
# Out:
# 8981.3239

# %%
df.groupby('Customer Name')['Profit'].sum() ==  df.groupby('Customer Name')['Profit'].sum().max()
# Out:
# Customer Name
# Aaron Bergman         False
# Aaron Hawkins         False
# Aaron Smayling        False
# Adam Bellavance       False
# Adam Hart             False
#                       ...
# Xylona Preis          False
# Yana Sorensen         False
# Yoseph Carroll        False
# Zuschuss Carroll      False
# Zuschuss Donatelli    False
# Name: Profit, Length: 793, dtype: bool

# %%
[df.groupby('Customer Name')['Profit'].sum() ==  df.groupby('Customer Name')['Profit'].sum().max() ]
# Out:
# [Customer Name
#  Aaron Bergman         False
#  Aaron Hawkins         False
#  Aaron Smayling        False
#  Adam Bellavance       False
#  Adam Hart             False
#                        ...
#  Xylona Preis          False
#  Yana Sorensen         False
#  Yoseph Carroll        False
#  Zuschuss Carroll      False
#  Zuschuss Donatelli    False
#  Name: Profit, Length: 793, dtype: bool]

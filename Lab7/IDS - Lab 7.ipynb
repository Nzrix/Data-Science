# %% [markdown]
# # Data Visualization with Seaborn - Exercises

# %% [markdown]
# ## The Data
#
# ใน exercise นี้ เราจะใช้ titanic data set ซึ่งเป็น Data ที่มีชื่อเสียงเป็นที่นิยม ซึ่งมีให้อยู่ใน library ของ seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** ให้นำ data ของ titanic ที่เป็น dataframe ไปใช้ทำการ plot ให้ตรงกับภาพดังต่อไปนี้**
#
# ** *Note! เพื่อไม่ให้ภาพที่ถูกต้องหาย อย่าลืม insert cell ขึ้นมาข้างบนใหม่มาขั้นก่อนทำการ run code จะได้ไม่ทำให้เกิดกันทับซ้อน (overwrite)* **

# %% [markdown]
# **จงทำการ plot ให้เหมือนกับรูปตัวอย่างด้านล่างนี้**

# %%
sns.jointplot(data = titanic, x = 'fare' , y = 'age')

# %% [markdown]
# **จงทำการ plot ให้เหมือนกับรูปตัวอย่างด้านล่างนี้**

# %%
plt.figure(figsize=[5,3])
sns.histplot(titanic['fare'],bins = 30,color='salmon')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# **จงทำการ plot ให้เหมือนกับรูปตัวอย่างด้านล่างนี้**

# %%
sns.boxplot(data = titanic, x = 'class' , y = 'age', palette='pastel')
# Out:
# C:\Users\pawar\AppData\Local\Temp\ipykernel_19604\3623707956.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = titanic, x = 'class' , y = 'age', palette='pastel')
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# **จงทำการ plot ให้เหมือนกับรูปตัวอย่างด้านล่างนี้**

# %%
plt.figure(figsize=[5,4])
sns.swarmplot(data = titanic, x = 'class' , y = 'age', palette='pastel')
# Out:
# C:\Users\pawar\AppData\Local\Temp\ipykernel_19604\1017227875.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data = titanic, x = 'class' , y = 'age', palette='pastel')
# c:\Users\pawar\Desktop\Code\DS\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='class', ylabel='age'>
# c:\Users\pawar\Desktop\Code\DS\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **จงทำการ plot ให้เหมือนกับรูปตัวอย่างด้านล่างนี้**

# %%
plt.figure(figsize=[5,4])
sns.countplot(data = titanic, x = 'sex',palette='tab10')
# Out:
# C:\Users\pawar\AppData\Local\Temp\ipykernel_19604\3819122286.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = titanic, x = 'sex',palette='tab10')
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# **จงทำการ plot ให้เหมือนกับรูปตัวอย่างด้านล่างนี้**

# %%
sns.heatmap(titanic[['survived', 'pclass' ,'age','sibsp','parch','fare','adult_male','alone']].corr(),cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# **จงทำการ plot ให้เหมือนกับรูปตัวอย่างด้านล่างนี้**

# %%
g = sns.FacetGrid(data=titanic,col='sex')
g.map(sns.histplot,'age',bins=10)

# %% [markdown]
# ### ----- ภาวนามยปัญญา ปัญญาที่เกิดจากการลงมือทำ! -----

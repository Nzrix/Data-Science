# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('electricity-consumptions.csv')
plt.figure(figsize=[6,4])
plt.scatter(df['home_size'],df['kilowatt_hours_per_month'])

# %%
from sklearn.linear_model import LinearRegression

att = df[['electricity-consumptions.csv']]
label = df['kilowatt_hours_per_month']

model = LinearRegression()
model.fit(att, label)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 from sklearn.linear_model import LinearRegression
# ----> 3 att = df[['electricity-consumptions.csv']]
#       4 label = df['kilowatt_hours_per_month']
#       6 model = LinearRegression()
#
# File c:\Users\pawar\Desktop\Code\Data-Science\.venv\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\pawar\Desktop\Code\Data-Science\.venv\Lib\site-packages\pandas\core\indexes\base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
# ...
